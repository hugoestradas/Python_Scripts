# %%
# !pip install waterfallcharts
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for waterfallcharts: filename=waterfallcharts-3.8-py3-none-any.whl size=3387 sha256=50544ed552114c858a049bb3f76fa37ae6fb1ec5065c48f5bd8764245f8c54d9
#   Stored in directory: /Users/hugoestradasmacstudio/Library/Caches/pip/wheels/29/0a/c2/f157617e1d611c0dc34f0d3f265fb811c2ab1a783e0725d566
# Successfully built waterfallcharts
# ...

# %%
import pandas as pd
import waterfall_chart as wc

df = pd.DataFrame({
    "Mes":['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio','Agosto', 'Septiembre'],
    "Delta":[12.1, -0.5, 1, 3, 3.5, 4, 5.2, 5.1, -2.8]})

# %%
wc.plot(df.Mes, df.Delta)
# Out:
# /Users/hugoestradasmacstudio/miniforge3/envs/py36/lib/python3.8/site-packages/waterfall_chart.py:71: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   step[1::3] = np.nan
# <module 'matplotlib.pyplot' from '/Users/hugoestradasmacstudio/miniforge3/envs/py36/lib/python3.8/site-packages/matplotlib/pyplot.py'>
