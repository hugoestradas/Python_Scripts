# %%
import os

# %%
PATH = '/Users/hugoestrada/'

# %%
fileCount = 0
dirCount =0

# %%
for root, dirs, files in os.walk(PATH):
    print('Looking in ', root)
    for directories in dirs:
        dirCount += 1
    for Files in files:
        fileCount += 1
# Out:
# Looking in  /Users/hugoestrada/
# Looking in  /Users/hugoestrada/.config
# Looking in  /Users/hugoestrada/.config/configstore
# Looking in  /Users/hugoestrada/.config/kitty
# Looking in  /Users/hugoestrada/Music
# Looking in  /Users/hugoestrada/Music/Music
# Looking in  /Users/hugoestrada/Music/Music/Media.localized
# Looking in  /Users/hugoestrada/Music/Music/Media.localized/.localized
# Looking in  /Users/hugoestrada/Music/Music/Media.localized/Automatically Add to Music.localized
# Looking in  /Users/hugoestrada/Music/Music/Media.localized/Automatically Add to Music.localized/.localized
# Looking in  /Users/hugoestrada/Music/Music/Music Library.musiclibrary
# Looking in  /Users/hugoestrada/Music/$RECYCLE.BIN
# Looking in  /Users/hugoestrada/.docker
# Looking in  /Users/hugoestrada/.docker/devenvironments
# Looking in  /Users/hugoestrada/.docker/contexts
# Looking in  /Users/hugoestrada/.docker/contexts/meta
# ...

# %%
print('Number of files ', fileCount)
print('Number of Directories ', dirCount)
print('Total: ',(dirCount+fileCount))
# Out:
# Number of files  137988
# Number of Directories  33892
# Total:  171880
